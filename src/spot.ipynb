# %%
# Instalação da biblioteca "ucilmlrepo", permite baixar o dataset neste colab sem ter que baixá-lo localmente
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.12/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2026.4.22)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
# Imports gerais e definição do rng

import pandas as pd
import numpy as np

from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    f1_score, recall_score, precision_score, accuracy_score,
    confusion_matrix, ConfusionMatrixDisplay,
    balanced_accuracy_score, RocCurveDisplay, PrecisionRecallDisplay
)
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt

import warnings
from sklearn.exceptions import ConvergenceWarning

# %%
# Download do dataset sem codificação
from ucimlrepo import fetch_ucirepo

# fetch dataset
car_evaluation = fetch_ucirepo(id=19)

# data (as pandas dataframes)
X = car_evaluation.data.features
y = car_evaluation.data.targets

print(X)
print(y)
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]
#       class
# 0     unacc
# 1     unacc
# 2     unacc
# 3     unacc
# 4     unacc
# ...     ...
# 1723   good
# 1724  vgood
# 1725  unacc
# 1726   good
# 1727  vgood
#
# [1728 rows x 1 columns]

# %%
# Codificação dos atributos do dataset

# Todos os atributos categóricos em ordem de menos para mais magnitude (por coincidência, todos os atributos desse dataset são categóricos ordinais)
categories = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety']
orders = [
            ['low', 'med', 'high', 'vhigh'],
            ['low', 'med', 'high', 'vhigh'],
            ['2', '3', '4', '5more'],
            ['2', '4', 'more'],
            ['small', 'med', 'big'],
            ['low', 'med', 'high']
        ]

# Encoder associa cada valor de cada ordem a um número de 0 a n-1 e então atualizamos o dataframe
encoder = OrdinalEncoder(categories=orders, dtype=np.int64)
encoder.set_output(transform="pandas") # Sem isso o encoder retorna um numpy array e não um dataframe pandas
X = encoder.fit_transform(X[categories])

print(X)
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 0          3      3      0        0         0       0
# 1          3      3      0        0         0       1
# 2          3      3      0        0         0       2
# 3          3      3      0        0         1       0
# 4          3      3      0        0         1       1
# ...      ...    ...    ...      ...       ...     ...
# 1723       0      0      3        2         1       1
# 1724       0      0      3        2         1       2
# 1725       0      0      3        2         2       0
# 1726       0      0      3        2         2       1
# 1727       0      0      3        2         2       2
#
# [1728 rows x 6 columns]

# %%
# Valores de rng fixos para garantir consistência (ADICIONE NOVOS À VONTADE)
RNG = [42, 94]

# Métricas usadas na avaliação
metricas = {
    'acurácia': 'accuracy',
    'acurácia_balanceada': 'balanced_accuracy',
    'recall': 'recall_macro',
    'precisão': 'precision_macro',
    'f1_micro': 'f1_micro',
    'f1_macro:': 'f1_macro',
    'roc_auc': 'roc_auc_ovr',
}

# Nomes dos algoritmos usados
nomes_algoritmos = [
    'Regressão Logística',
    'KNN',
    'Árvore de Decisão',
    'Rede Neural',
    'Naive Bayes',
    'SVM'
  ]

# %%
testing = True # Booleana para testes, usada para desativar aviso de que a rede neural chegou no máximo de iterações sem convergir. Desativar no spot checking final

# Spot checking
scores_raw = [] # Os valores em cada seed, de cada algoritmo, para cada métrica
scores = [] # A média e desvio padrão em cada seed, de cada algoritmo, para cada métrica
y_tests = [] # Guarda os valores de 'y_test' de cada split (necessário para o gráfico de matriz de confusão)
y_preds = {nome: [] for nome in nomes_algoritmos} # Guarda os valores de 'y_pred' de cada modelo (necessário para o gráfico de matriz de confusão)
for i, rng in enumerate(RNG):
  scores.append({})
  scores_raw.append({})
  # Construção de algoritmos com hiperparâmetros fixos, apenas mudando a seed de rng, se for aplicável.
  algoritimos = {
      nomes_algoritmos[0]: LogisticRegression(random_state=rng, max_iter=200),
      nomes_algoritmos[1]: KNeighborsClassifier(n_neighbors=5),
      nomes_algoritmos[2]: DecisionTreeClassifier(max_depth=8, ccp_alpha=0.01, random_state=rng),
      nomes_algoritmos[3]: MLPClassifier(random_state=rng, max_iter=200), # com max_iter < 2000 não termina de convergir, mas se não tiver acima de 2000 ou não tiver demora MUITO tempo pra convergir totalmente (AUMENTAR NO SPOT FINAL)
      nomes_algoritmos[4]: GaussianNB(),
      nomes_algoritmos[5]: SVC(random_state=rng, probability=True)
  }

  # Split treino/teste
  X_train, X_test, y_train, y_test = train_test_split(
      # Aqui y é transformado do formato Dataframe para um array unidimensional com .ravel()
      # Se não fizer isso, a função cross_val_score reclama
      X, y.values.ravel(), test_size=0.2, stratify=y.values.ravel(), random_state=rng
  )
  # Guardando conjunto de teste do split para uso na matriz de confusão
  y_tests.append(y_test)

  # Sem nested cross validation pois não faremos otimização de hiperparâmetros nessa etapa
  # Possivelmente mudar n_splits?
  cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=rng)

  # Testar a separação atual para cada algoritmo
  for nome_algoritmo, model in algoritimos.items():
    scores[i][nome_algoritmo] = {}
    scores_raw[i][nome_algoritmo] = {}
    # Treino do modelo atual
    if testing:
      warnings.simplefilter("ignore", category=ConvergenceWarning) # Desativa o aviso de que a Rede Neural não convergiu (lembre de colocar testing = Flase quando for feito o spot final)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    # Guardando valores previstos pelo modelo nesse split para uso na matriz de confusão
    y_preds[nome_algoritmo].append(y_pred)
    for nome_metrica, metrica in metricas.items():
      # Testando o modelo para cada métrica com stratified-k-fold e guarrdando os scores
      score = cross_val_score(estimator=model, X=X_train, y=y_train, cv=cv, scoring=metrica)
      scores_raw[i][nome_algoritmo][nome_metrica] = score
      scores[i][nome_algoritmo][nome_metrica] = {'media': float(score.mean()), 'desvio_padrao': float(score.std())}


  for i, score in enumerate(scores):
    print(f'Split de dados {i+1}, seed {RNG[i]}:')
    for nome in nomes_algoritmos:
      print(f'  Resultados do spot cheking para {nome}:')
      for metrica in metricas.keys():
        print(f'    {metrica} -> média: {score[nome][metrica]['media']:.4}, desvio padrão: {score[nome][metrica]["desvio_padrao"]:.4}')
# Out:
# Regressão Logística y_pred: ['good' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'good' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'acc'
#  'vgood' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'good'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'acc' 'unacc' 'vgood' 'good'
#  'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'acc' 'unacc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'good' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'good' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc']
# KNN y_pred: ['good' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'good'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'good' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc'
#  'vgood' 'unacc' 'good' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'acc' 'vgood' 'acc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'good' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc'
#  'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'vgood' 'acc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'good' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'good' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'good'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc']
# Árvore de Decisão y_pred: ['acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'vgood'
#  'unacc' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'good' 'acc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'good' 'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'acc'
#  'acc' 'unacc' 'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'acc' 'unacc'
#  'unacc' 'vgood' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'good' 'acc' 'vgood' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'acc' 'unacc'
#  'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc']
# Rede Neural y_pred: ['good' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'good'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc'
#  'vgood' 'unacc' 'good' 'unacc' 'good' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'good' 'acc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'acc' 'vgood' 'vgood'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'vgood' 'unacc' 'unacc' 'acc' 'good' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'vgood' 'good' 'unacc' 'unacc'
#  'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'vgood' 'acc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'good' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc'
#  'unacc' 'good' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'good' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'acc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc']
# Naive Bayes y_pred: ['good' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood'
#  'unacc' 'unacc' 'vgood' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'acc' 'vgood' 'unacc'
#  'vgood' 'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'good' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'good' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'vgood' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood' 'unacc' 'vgood' 'vgood'
#  'vgood' 'vgood' 'vgood' 'vgood' 'unacc' 'unacc' 'acc' 'acc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'vgood' 'vgood' 'vgood'
#  'unacc' 'unacc' 'unacc' 'vgood' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood'
#  'vgood' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'vgood' 'vgood' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'vgood' 'vgood'
#  'vgood' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'vgood' 'unacc' 'unacc' 'good' 'vgood' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'vgood' 'acc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'good' 'vgood' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc']
# SVM y_pred: ['good' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'good'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc'
#  'vgood' 'unacc' 'good' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'good' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'acc' 'good' 'unacc' 'acc' 'vgood' 'vgood' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'vgood' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'vgood' 'good' 'unacc' 'unacc'
#  'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'vgood' 'acc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc'
#  'good' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'acc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc']
# Split de dados 1, seed 42:
#   Resultados do spot cheking para Regressão Logística:
#     acurácia -> média: 0.8234, desvio padrão: 0.02087
#     acurácia_balanceada -> média: 0.658, desvio padrão: 0.06338
#     recall -> média: 0.658, desvio padrão: 0.06338
#     precisão -> média: 0.7372, desvio padrão: 0.07471
#     f1_micro -> média: 0.8234, desvio padrão: 0.02087
#     f1_macro: -> média: 0.676, desvio padrão: 0.06232
#     roc_auc -> média: 0.9468, desvio padrão: 0.005718
#   Resultados do spot cheking para KNN:
#     acurácia -> média: 0.9421, desvio padrão: 0.009989
#     acurácia_balanceada -> média: 0.8505, desvio padrão: 0.04257
#     recall -> média: 0.8505, desvio padrão: 0.04257
#     precisão -> média: 0.9179, desvio padrão: 0.02722
#     f1_micro -> média: 0.9421, desvio padrão: 0.009989
#     f1_macro: -> média: 0.8759, desvio padrão: 0.02522
#     roc_auc -> média: 0.9865, desvio padrão: 0.003834
#   Resultados do spot cheking para Árvore de Decisão:
#     acurácia -> média: 0.8987, desvio padrão: 0.03115
#     acurácia_balanceada -> média: 0.7394, desvio padrão: 0.05274
#     recall -> média: 0.7394, desvio padrão: 0.05274
#     precisão -> média: 0.7863, desvio padrão: 0.05744
#     f1_micro -> média: 0.8987, desvio padrão: 0.03115
#     f1_macro: -> média: 0.7422, desvio padrão: 0.04837
#     roc_auc -> média: 0.9751, desvio padrão: 0.005994
#   Resultados do spot cheking para Rede Neural:
#     acurácia -> média: 0.9255, desvio padrão: 0.01967
#     acurácia_balanceada -> média: 0.8367, desvio padrão: 0.04421
#     recall -> média: 0.8367, desvio padrão: 0.04421
#     precisão -> média: 0.868, desvio padrão: 0.03765
#     f1_micro -> média: 0.9255, desvio padrão: 0.01967
#     f1_macro: -> média: 0.8436, desvio padrão: 0.03739
#     roc_auc -> média: 0.9902, desvio padrão: 0.004146
#   Resultados do spot cheking para Naive Bayes:
#     acurácia -> média: 0.7004, desvio padrão: 0.01724
#     acurácia_balanceada -> média: 0.572, desvio padrão: 0.02555
#     recall -> média: 0.572, desvio padrão: 0.02555
#     precisão -> média: 0.5462, desvio padrão: 0.04734
#     f1_micro -> média: 0.7004, desvio padrão: 0.01724
#     f1_macro: -> média: 0.4438, desvio padrão: 0.02717
#     roc_auc -> média: 0.8991, desvio padrão: 0.007017
#   Resultados do spot cheking para SVM:
#     acurácia -> média: 0.9522, desvio padrão: 0.01265
#     acurácia_balanceada -> média: 0.8804, desvio padrão: 0.03888
#     recall -> média: 0.8804, desvio padrão: 0.03888
#     precisão -> média: 0.9263, desvio padrão: 0.02332
#     f1_micro -> média: 0.9522, desvio padrão: 0.01265
#     f1_macro: -> média: 0.8947, desvio padrão: 0.01887
#     roc_auc -> média: 0.9964, desvio padrão: 0.002158
# Regressão Logística y_pred: ['unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'good' 'good'
#  'unacc' 'acc' 'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'acc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'good' 'acc' 'unacc' 'unacc' 'vgood'
#  'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'vgood' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc'
#  'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'vgood' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'good' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'good'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'vgood']
# KNN y_pred: ['unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good'
#  'acc' 'unacc' 'acc' 'unacc' 'acc' 'good' 'acc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'vgood' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'acc' 'unacc'
#  'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'good' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'vgood' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'acc' 'unacc'
#  'unacc' 'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'good' 'unacc' 'vgood' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'good' 'unacc' 'vgood' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'good' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'good']
# Árvore de Decisão y_pred: ['unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'acc' 'unacc' 'acc' 'unacc' 'acc' 'vgood' 'acc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'acc' 'vgood' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'good'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'acc'
#  'acc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'vgood' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'vgood' 'acc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'acc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'good' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'good' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good'
#  'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'acc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc'
#  'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'vgood' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'acc'
#  'acc' 'unacc' 'vgood']
# Rede Neural y_pred: ['unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good'
#  'good' 'unacc' 'acc' 'unacc' 'acc' 'vgood' 'acc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc'
#  'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'good' 'unacc' 'unacc' 'acc'
#  'unacc' 'good' 'vgood' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'vgood' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'good' 'unacc' 'acc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'good' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'good' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'good' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'good'
#  'good' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'vgood'
#  'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'vgood']
# Naive Bayes y_pred: ['unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'good'
#  'good' 'unacc' 'vgood' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'vgood'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'vgood' 'acc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'vgood' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'vgood'
#  'vgood' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'unacc'
#  'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'vgood'
#  'acc' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc' 'vgood'
#  'good' 'unacc' 'unacc' 'vgood' 'unacc' 'good' 'vgood' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'vgood' 'acc' 'unacc' 'vgood' 'acc' 'unacc' 'vgood' 'vgood'
#  'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood' 'acc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'good' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'vgood' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'acc' 'vgood' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc'
#  'vgood' 'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'acc' 'unacc'
#  'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'vgood' 'unacc' 'vgood' 'unacc'
#  'vgood' 'vgood' 'unacc' 'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc'
#  'unacc' 'vgood' 'unacc' 'unacc' 'vgood' 'vgood' 'unacc' 'unacc' 'vgood'
#  'acc' 'unacc' 'vgood']
# SVM y_pred: ['unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'good'
#  'good' 'unacc' 'acc' 'unacc' 'acc' 'vgood' 'acc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'good' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood'
#  'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'vgood'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'vgood' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'unacc' 'unacc'
#  'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc' 'good' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'good' 'unacc' 'unacc' 'unacc'
#  'unacc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'vgood' 'acc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc' 'acc' 'acc' 'unacc' 'acc'
#  'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'vgood' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'good' 'acc' 'unacc' 'unacc'
#  'unacc' 'acc' 'vgood' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'good' 'unacc' 'vgood' 'unacc' 'acc' 'unacc' 'unacc'
#  'acc' 'acc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'acc' 'acc' 'unacc' 'acc' 'unacc'
#  'unacc' 'acc' 'good' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc'
#  'unacc' 'acc' 'vgood' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'acc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc'
#  'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'good' 'unacc' 'acc'
#  'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'good' 'unacc' 'vgood' 'acc' 'unacc' 'unacc' 'unacc' 'unacc' 'unacc'
#  'unacc' 'unacc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'unacc' 'good'
#  'good' 'unacc' 'unacc' 'acc' 'unacc' 'acc' 'unacc' 'unacc' 'acc' 'vgood'
#  'unacc' 'unacc' 'acc' 'acc' 'unacc' 'unacc' 'acc' 'unacc' 'unacc' 'vgood']
# Split de dados 1, seed 42:
#   Resultados do spot cheking para Regressão Logística:
#     acurácia -> média: 0.8234, desvio padrão: 0.02087
#     acurácia_balanceada -> média: 0.658, desvio padrão: 0.06338
#     recall -> média: 0.658, desvio padrão: 0.06338
#     precisão -> média: 0.7372, desvio padrão: 0.07471
#     f1_micro -> média: 0.8234, desvio padrão: 0.02087
#     f1_macro: -> média: 0.676, desvio padrão: 0.06232
#     roc_auc -> média: 0.9468, desvio padrão: 0.005718
#   Resultados do spot cheking para KNN:
#     acurácia -> média: 0.9421, desvio padrão: 0.009989
#     acurácia_balanceada -> média: 0.8505, desvio padrão: 0.04257
#     recall -> média: 0.8505, desvio padrão: 0.04257
#     precisão -> média: 0.9179, desvio padrão: 0.02722
#     f1_micro -> média: 0.9421, desvio padrão: 0.009989
#     f1_macro: -> média: 0.8759, desvio padrão: 0.02522
#     roc_auc -> média: 0.9865, desvio padrão: 0.003834
#   Resultados do spot cheking para Árvore de Decisão:
#     acurácia -> média: 0.8987, desvio padrão: 0.03115
#     acurácia_balanceada -> média: 0.7394, desvio padrão: 0.05274
#     recall -> média: 0.7394, desvio padrão: 0.05274
#     precisão -> média: 0.7863, desvio padrão: 0.05744
#     f1_micro -> média: 0.8987, desvio padrão: 0.03115
#     f1_macro: -> média: 0.7422, desvio padrão: 0.04837
#     roc_auc -> média: 0.9751, desvio padrão: 0.005994
#   Resultados do spot cheking para Rede Neural:
#     acurácia -> média: 0.9255, desvio padrão: 0.01967
#     acurácia_balanceada -> média: 0.8367, desvio padrão: 0.04421
#     recall -> média: 0.8367, desvio padrão: 0.04421
#     precisão -> média: 0.868, desvio padrão: 0.03765
#     f1_micro -> média: 0.9255, desvio padrão: 0.01967
#     f1_macro: -> média: 0.8436, desvio padrão: 0.03739
#     roc_auc -> média: 0.9902, desvio padrão: 0.004146
#   Resultados do spot cheking para Naive Bayes:
#     acurácia -> média: 0.7004, desvio padrão: 0.01724
#     acurácia_balanceada -> média: 0.572, desvio padrão: 0.02555
#     recall -> média: 0.572, desvio padrão: 0.02555
#     precisão -> média: 0.5462, desvio padrão: 0.04734
#     f1_micro -> média: 0.7004, desvio padrão: 0.01724
#     f1_macro: -> média: 0.4438, desvio padrão: 0.02717
#     roc_auc -> média: 0.8991, desvio padrão: 0.007017
#   Resultados do spot cheking para SVM:
#     acurácia -> média: 0.9522, desvio padrão: 0.01265
#     acurácia_balanceada -> média: 0.8804, desvio padrão: 0.03888
#     recall -> média: 0.8804, desvio padrão: 0.03888
#     precisão -> média: 0.9263, desvio padrão: 0.02332
#     f1_micro -> média: 0.9522, desvio padrão: 0.01265
#     f1_macro: -> média: 0.8947, desvio padrão: 0.01887
#     roc_auc -> média: 0.9964, desvio padrão: 0.002158
# Split de dados 2, seed 94:
#   Resultados do spot cheking para Regressão Logística:
#     acurácia -> média: 0.8278, desvio padrão: 0.01222
#     acurácia_balanceada -> média: 0.6526, desvio padrão: 0.04201
#     recall -> média: 0.6526, desvio padrão: 0.04201
#     precisão -> média: 0.6953, desvio padrão: 0.03286
#     f1_micro -> média: 0.8278, desvio padrão: 0.01222
#     f1_macro: -> média: 0.6655, desvio padrão: 0.03703
#     roc_auc -> média: 0.952, desvio padrão: 0.006725
#   Resultados do spot cheking para KNN:
#     acurácia -> média: 0.9255, desvio padrão: 0.006698
#     acurácia_balanceada -> média: 0.7605, desvio padrão: 0.03499
#     recall -> média: 0.7605, desvio padrão: 0.03499
#     precisão -> média: 0.8478, desvio padrão: 0.03408
#     f1_micro -> média: 0.9255, desvio padrão: 0.006698
#     f1_macro: -> média: 0.7912, desvio padrão: 0.02695
#     roc_auc -> média: 0.9817, desvio padrão: 0.006067
#   Resultados do spot cheking para Árvore de Decisão:
#     acurácia -> média: 0.9096, desvio padrão: 0.01818
#     acurácia_balanceada -> média: 0.737, desvio padrão: 0.03461
#     recall -> média: 0.737, desvio padrão: 0.03461
#     precisão -> média: 0.8234, desvio padrão: 0.04792
#     f1_micro -> média: 0.9096, desvio padrão: 0.01818
#     f1_macro: -> média: 0.7469, desvio padrão: 0.02911
#     roc_auc -> média: 0.9765, desvio padrão: 0.003392
#   Resultados do spot cheking para Rede Neural:
#     acurácia -> média: 0.9356, desvio padrão: 0.014
#     acurácia_balanceada -> média: 0.8675, desvio padrão: 0.04954
#     recall -> média: 0.8675, desvio padrão: 0.04954
#     precisão -> média: 0.8863, desvio padrão: 0.03193
#     f1_micro -> média: 0.9356, desvio padrão: 0.014
#     f1_macro: -> média: 0.8737, desvio padrão: 0.03853
#     roc_auc -> média: 0.9917, desvio padrão: 0.002717
#   Resultados do spot cheking para Naive Bayes:
#     acurácia -> média: 0.7142, desvio padrão: 0.01874
#     acurácia_balanceada -> média: 0.5817, desvio padrão: 0.02399
#     recall -> média: 0.5817, desvio padrão: 0.02399
#     precisão -> média: 0.5736, desvio padrão: 0.05199
#     f1_micro -> média: 0.7142, desvio padrão: 0.01874
#     f1_macro: -> média: 0.4612, desvio padrão: 0.03404
#     roc_auc -> média: 0.9011, desvio padrão: 0.005859
#   Resultados do spot cheking para SVM:
#     acurácia -> média: 0.9544, desvio padrão: 0.008375
#     acurácia_balanceada -> média: 0.8687, desvio padrão: 0.0236
#     recall -> média: 0.8687, desvio padrão: 0.0236
#     precisão -> média: 0.9275, desvio padrão: 0.03344
#     f1_micro -> média: 0.9544, desvio padrão: 0.008375
#     f1_macro: -> média: 0.8934, desvio padrão: 0.02201
#     roc_auc -> média: 0.9962, desvio padrão: 0.002265

# %%
# Box-Plots dos scores
# Uma coluna de gráficos para cada métrica, contendo len(RNG) gráficos comparando o desempenho de cada algoritmo em uma seed de RNG
num_seeds = len(RNG)

plt.rcParams['figure.dpi'] = 150  # Melhora a resolução

for metrica in metricas.keys():
    fig, axes = plt.subplots(1, num_seeds, figsize=(5*num_seeds, 5))

    # Conserta as dimensões dos eixos se só temos uma seed
    if num_seeds == 1:
        axes = [axes]

    for i, seed in enumerate(RNG):
        ax = axes[i]

        data = []
        for nome in nomes_algoritmos:
            data.append(scores_raw[i][nome][metrica])

        ax.boxplot(data, tick_labels=nomes_algoritmos)
        ax.set_title(f"Seed = {seed}")
        ax.set_xlabel("Algoritmos")
        ax.set_ylabel(metrica)
        ax.tick_params(axis='x', rotation=45)

    fig.suptitle(f"Comparação de {metrica}", fontsize=16)

    plt.subplots_adjust(wspace=0.3)
    plt.show()

# %%
# Matrizes de confusão das predições

nomes_classes = ["unacc", "acc", "good", "vgood"]

for nome in nomes_algoritmos:
    y_tests_axis = np.concatenate(y_tests)
    y_pred_axis = np.concatenate(y_preds[nome])

    cm = confusion_matrix(y_tests_axis, y_pred_axis)

    fig, ax = plt.subplots(figsize=(6,6))
    ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=nomes_classes).plot(ax=ax)

    ax.set_title(f"Matriz de Confusão - {nome}")
    plt.show()
